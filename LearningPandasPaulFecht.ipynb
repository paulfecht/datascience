# %% [markdown]
# # Using Pandas & NumPy & MatPlotLib
# ## Data Visualization Is Storytelling
# #### Things to keep in mind
#
# <h4>MatPlotLib is a programmatic visualization framework</h4>
# <ul>
#     <li> 5 Key steps to Data Science Projects
#         <ul>
#             <li>Data Acquistion
#                 <ul>
#                     <li><a href/"https://www.theguardian.com/sport/datablog/2012/jun/25/olympic-medal-winner-list-data#data"> Olympic Data</a></li>
#                     <li><a href="https://data.worldbank.org/indicator/NY.GDP.MKTP.CD?name_desc=false">GDP Source #1</a></li>
#                     <li><a href="https://www.ers.usda.gov/data-products/international-macroeconomic-data-set.aspx">GDP Source #2</a></li>
#                 </ul>
#             </li>
#             <li>Data Preparation</li>
#             <li>Data Analysis</li>
#             <li>Presentation</li>
#             <li>Reporting of Insights</li>
#         </ul>
#     </li>
#     <li>Good data sources
#         <ul>
#             <li><a href="https://www.data.gov/">Data.gov</a> In easy to use .csv formats.</li>
#             <li><a href="https://www.cia.gov/library/publications/download">World FactBook</a> World Factbook CIA, link is to download the entire World FactBook</li>
#             <li>World Health Data <a href="http://www.who.int/gho/en/">here</a></li>
#             <li>Quandl - https://www.quandl.com/ </li>
#             <li>Amazon Web Services(AWS) Public Data Sets <a href="https://registry.opendata.aws/">here</a> Be aware the datasets are large and they may try an rope you into a paid service.</li>
#             <li>Web Scraping
#                 <ul>
#                     <li>Wealth of underused information online</li>
#                     <li>Check for a public API</li>
#                     <li>Ask if it's allowed</li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
#
#     <li>Book: <a href="https://www.amazon.com/How-Lie-Statistics-Darrell-Huff/dp/0393310728"> How To Lie With Statistics </a> </li>
#
#     <li>Clearly define the story
#         <ul>
#             <li>Before you look at the data</li>
#             <li>Blindy data mining === bad time</li>
#             <li>What should the visualization communicate?</li>
#         </ul>
#      </li>
#      <li>Pick the right chart
#         <ul>
#             <li>What chart tells your story?
#                 <ol>
#                     <li>... without adding too much information?</li>
#                     <li>Histogram should be the first chart you make when you start working with a new data set.</li>
#                     <li>Box Plots summarize distributions
#                         <ul>
#                             <li>Compare Distributions</li>
#                             <li>Useful for spotting outliers</li>
#                         </ul>
#                     </li>
#                     <li>Scatter plots can be used to establish relationships between variables.
#                         <ul>
#                             <li>Powerful chart</li>
#                             <li>Establish correlation
#                                 <ul>
#                                     <li><strong>Not</strong> causation</li>
#                                 </ul>
#                             </li>
#                             <li>Can scale dot size to show third variable</li>
#                         </ul>
#                     </li>
#                 </ol>
#             </li>
#             <li>
#                 <ul>
#                     <li><strong>Bar</strong> and <strong>Line</strong> charts are the most used charts
#                         <ul>
#                             <li>Simple to understand</li>
#                             <li>Effective at communicating data</li>
#                             <li><strong>use whenever you can !!!</strong></li>
#                         </ul>
#                     </li>
#                 </ul>
#             </li>
#             <li></li>
#         </ul>
#      </li>
#      <li>Assess your visualization
#         <ul>
#             <li>Can you immediately see the story?
#                 <ul>
#                     <li></li>
#                 </ul>
#             </li>
#             <li>Are there distractions, in the visualization that pull the reader from the main story?
#                  <ul>
#                     <li>If yes, start over</li>
#                 </ul>
#             </li>
#         </ul>
#      </li>
#      <li>Don't give the reader information overload.
#
#      </li>
#      <li>Common new comer mistakes.
#          <ul>
#              <li>Unlabeled Charts
#                  <ul>
#                      <li>Most common mistake</li>
#                      <li>Can make your visualization useless</li>
#                      <table style="width:100%">
#                       <tr>
#                         <th style="text-align:center;">Bad</th>
#                         <th style="text-align:center;">Good</th>
#
#                       </tr>
#                       <tr>
#                         <td><img src="images/unlabeledChartBadExample.png", width=50%, height=50%></td>
#                         <td><img src="images/unlabeledChartGoodExample.png", width=50%, height=50%></td>
#
#                       </tr>
#                     </table>
#                     <li>Start bar charts at 0</li>
#                     <li>Normalize you data
#                         <ul>
#                             <li>A visualization that I like( <a href="https://www.reddit.com/r/dataisugly/comments/8cfovj/because_brackets_make_too_much_sense/">here</a> )              </li>
#                         </ul>
#                     </li>
#                     <li>Attach labels directly to the data if possible</li>
#                     <li>Squint test, can you gauge anything about the visualization whilst squinting?</li>
#                     <li>Strive for reproducibility</li>
#                     <li>Share the exact link so people can easily find your data.</li>
#                     <li>Describe your methods in detail.</li>
#                     <li>Bad Visualizations
#                         <ul>
#                         <li>http://viz.wtf/</li>
#                         <li>https://www.reddit.com/r/dataisugly/</li>
#                         </ul>
#                     </li>
#                  </ul>
#               </li>
#          </ul>
#      </li>
# </ul>

# %% [markdown]
# ## Importing pandas

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pandas.__version__
# Out:
# '0.20.3'

# %%
import pandas as pd  #sets an alias for pandas

# %%
pd.__version__      # type pd.<tab> and you'll get the available methods in the Pandas library
# Out:
# '0.20.3'

# %% [markdown]
# ## Pandas documentation

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.3.final.0
# python-bits: 64
# OS: Darwin
# OS-release: 15.6.0
# machine: x86_64
# processor: i386
# byteorder: little
# LC_ALL: en_US.UTF-8
# LANG: en_US.UTF-8
# LOCALE: en_US.UTF-8
#
# pandas: 0.20.3
# pytest: 3.2.1
# pip: 9.0.1
# setuptools: 36.5.0.post20170921
# Cython: 0.26.1
# numpy: 1.13.3
# scipy: 0.19.1
# xarray: None
# IPython: 6.1.0
# sphinx: 1.6.3
# patsy: 0.4.1
# dateutil: 2.6.1
# pytz: 2017.2
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.2
# numexpr: 2.6.2
# feather: None
# matplotlib: 2.1.0
# openpyxl: 2.4.8
# xlrd: 1.1.0
# xlwt: 1.2.0
# xlsxwriter: 1.0.2
# lxml: 4.1.0
# bs4: 4.6.0
# html5lib: 0.999999999
# sqlalchemy: 1.1.13
# pymysql: None
# psycopg2: None
# jinja2: 2.9.6
# s3fs: None
# pandas_gbq: None
# pandas_datareader: None

# %%
pd.show_versions?

# %%
pd.read_csv?

# %%
pd.read_csv('/Users/paulfechtmeister/Documents/GraduateSchoolApplicationSummer2016/DataScienceSecurity/LearningJupyterNotebooks/test.csv')
# Out:
#     name   age  Unnamed: 2
# 0   paul    49         NaN
# 1  misty    45         NaN

# %%
pwd
# Out:
# '/Users/paulfechtmeister/Documents/Lynda_Learning/Ex_Files_Pandas_EssT/ExerciseFiles/Ch01'

# %%
oo = pd.read_csv('../data/olympics.csv', skiprows=4) #read CSV into a dataframe called "oo"
#                                           |
#   Allows us to skip the top 4 rows in the spreadsheet which 
#   is just text. So we can get down to the column headings.
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo.City  # can only use the dot (.) notation when there are no spaces " " in the column name
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
type(oo.City)
# Out:
# pandas.core.series.Series

# %%
type(oo['NOC'])
# Out:
# pandas.core.series.Series

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo[['Edition', 'City', 'Athlete','Medal']]
# Out:
#        Edition     City                      Athlete   Medal
# 0         1896   Athens                HAJOS, Alfred    Gold
# 1         1896   Athens             HERSCHMANN, Otto  Silver
# 2         1896   Athens            DRIVAS, Dimitrios  Bronze
# 3         1896   Athens           MALOKINIS, Ioannis    Gold
# 4         1896   Athens           CHASAPIS, Spiridon  Silver
# 5         1896   Athens        CHOROPHAS, Efstathios  Bronze
# 6         1896   Athens                HAJOS, Alfred    Gold
# 7         1896   Athens             ANDREOU, Joannis  Silver
# 8         1896   Athens        CHOROPHAS, Efstathios  Bronze
# 9         1896   Athens                NEUMANN, Paul    Gold
# 10        1896   Athens            PEPANOS, Antonios  Silver
# 11        1896   Athens                LANE, Francis  Bronze
# 12        1896   Athens             SZOKOLYI, Alajos  Bronze
# 13        1896   Athens                BURKE, Thomas    Gold
# ...

# %%
type(oo[['Edition', 'City', 'Athlete','Medal']])
# Out:
# pandas.core.frame.DataFrame

# %%
oo = pd.read_csv('../data/olympics.csv', skiprows=4)

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo.shape
# This will return (29220 , 10)
#                     |      |
#                  rows   columns
# Out:
# (29216, 10)

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# <h2> value_counts() </h2>

# %%
# If I wanted to know how many medals were awarded each time the olympics were held.
oo.Edition.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-38ca91a5c7e2> in <module>()
#       1 # If I wanted to know how many medals were awarded each time the olympics were held.
# ----> 2 oo.Edition.value_counts()
#
# NameError: name 'oo' is not defined

# %%
oo.Gender.value_counts(ascending=True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# <h2> sort_values() </h2>

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo.sort_values(by=['Edition','Athlete'])
# sort by             |          |
#                  this 1st, then this
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Let's say we wanted to select all the athletes that have won a gold medal.
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %%
# Looking for Florence Griffiths-Joyner from USA the world's fastest woman.
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# <h2>What events did Jesse Owens compete in? </h2>

# %%
oo[oo.Athlete.str.contains('OWENS')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %% [markdown]
# <h2> Gold medals in Men's Singles Badminton since its inception as an olympic sport. </h2>

# %%
players = oo[oo.Sport.str.contains('Badminton') & (oo.Gender == 'Men') & (oo.Event == 'singles') & (oo.Medal == 'Gold')]
players.Athlete.sort_values()
players.sort_values(by=['NOC'])
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
#
#       Gender    Event Event_gender Medal
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold

# %% [markdown]
# <h2>Top 3 Countries with the most medals from 1984 until end of the data set</h2>

# %%
badmitters = oo[(oo.Edition > 1980)]
badmitters.NOC.value_counts(dropna=False).nlargest(3)
 #       oo.nlargest(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# <h2>Display the male gold medal winners for the 100m track and field sprint event over the years.</h2>

# %%
gmh = oo[(oo.Event == '100m') & (oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Discipline == 'Athletics')]
gmh.sort_values("Edition", ascending=False)[['City', 'Edition', 'Athlete', 'NOC']].head()
#oo[['City', 'Edition', 'Athlete','NOC']]
# Out:
#             City  Edition            Athlete  NOC
# 27552    Beijing     2008        BOLT, Usain  JAM
# 25539     Athens     2004     GATLIN, Justin  USA
# 23521     Sydney     2000    GREENE, Maurice  USA
# 21598    Atlanta     1996    BAILEY, Donovan  CAN
# 19859  Barcelona     1992  CHRISTIE, Linford  GBR

# %% [markdown]
# <h2>Plot types</h2>
# <h3> What were the different sports in the first olympics? Plot them using different graphs. </h3>

# %%
firstOlympics = oo[oo.Edition == 1896]
firstOlympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
firstOlympics.Sport.value_counts().plot(kind = 'line');

# %% [markdown]
# <p> you can suppress the output
# <h3>Note: you displayed the line below using the backtick which is on the tilde key.</h3>
# `<matplotlib.axes._subplots.AxesSubplot at 0x119eb4128>` </p>
# <p style="display:inline"> By terminating your statement with a </p> <h1 style="display:inline; font-size: 4em;"> ; </h1>

# %% [markdown]
# ### Line charts are for showing trends in data with more than a few time points.

# %%
firstOlympics.Sport.value_counts().plot();

# %% [markdown]
# <p>For this data a bar chart will be clearer than a line graph
# that is because by inspection we can see that<br> the sport with the
# most athletes competing was Gymnastics.</p>
# <h1>Bar plot - Column Chart - Vertical Bar Chart</h1>

# %%
firstOlympics.Sport.value_counts().plot(kind='bar');

# %% [markdown]
# <h2>Horizontal Bar plot
# </h2>

# %%
firstOlympics.Sport.value_counts().plot(kind='barh');

# %% [markdown]
# <h1> Pie chart </h1>

# %%
firstOlympics.Sport.value_counts().plot(kind='pie');

# %% [markdown]
# <h2>In this instance the Bar charts and the pie charts are best for representing <br> this data.  Don't use
# the line graph here, due to its difficulty in interpretation.</h2>

# %% [markdown]
# <h2>plot colors</h2>

# %%
firstOlympics.Sport.value_counts().plot(color='plum'); # gives the default line plot in the color of plum

# %% [markdown]
# <h3 style="display:inline">Notice in the above</h3><h1 style="display:inline">&uarr;</h1><h3 style="display:inline"> there's not enough room for the x-axis labels.</h3>

# %%
firstOlympics.Sport.value_counts().plot(kind='bar',color='yellow');

# %% [markdown]
# <h2>figsize() &nbsp; &nbsp; Manipulating the size of the Figure </h2>
# <p>The figure size is a tuple where you can specify the size </br>
# in inches. <br>
# <em>plot(figsize=(width,height))</em>
# <br>&nbsp;&nbsp;&nbsp; <b>plot(kind='bar', color='yellow',figsize(5,5) </b>
#
# </p>

# %%
firstOlympics.Sport.value_counts().plot(figsize=(10,3));

# %% [markdown]
# <h2 style="display:inline">Colormaps</h2> Before you settle on a color scheme run your color scheme through a color blindness simulator to see if it checks out. (<a target="_blank" href="http://www.color-blindness.com/coblis-color-blindness-simulator/" target="_blank"> here </a> )  It should also print well. Seaborn has integrated ColorBrewer<a href="http://colorbrewer2.org">ColorBrewer</a>
# <h3 style="display:inline">
# <a href="https://matplotlib.org/users/colormaps.html#ware"> reference</h3>
# <h2 style="display:inline">- think, is there a color scheme for the data<br> (e.g. Gold: yellow, Silver:grey, Bronze: brownish)</h2>
# <ul>
#     <li> <h4>Classes of colormaps</h4>
#     <ul>
#         <li>Sequential - when the data has ordering. Like when there is a range of values. The image below could encode the amount of rain that a city receives each day.  Light blue meaning little and dark blue meaning a lot.
#             <img src="images/sequentialColorScheme.png", width=350, height=57>
#         </li>
#         <li>Diverging - when the info deviates around a middle value.  Used to visually encode a range of values that have an obvious diving point.  A companies gains and loses.  Red = loss, Blue = surplus, White = break even.
#             <img src="images/divergingColorScheme.png", width=350, height=57>
#         </li>
#         <li>Qualitative - when there is no ordering or obvious relationship. (e.g. different programming languages)
#             <img src="images/qualitativeColorScheme.png", width=350, height=57>
#         </li>
#     </ul>
#     </li>
# </ul>

# %%
firstOlympics.Sport.value_counts().plot(kind='pie',colormap='Pastel1');

# %% [markdown]
# <h2>Using Seaborn for basic plotting</h2>

# %%
import seaborn as sns

# %% [markdown]
# ### How many medals have been won by men and women in the history of the Olympics.  How many gold, silver and bronze medals in total have been won regardless of gender.

# %%
sns.countplot(x='Medal',data=oo, hue ='Gender');

# %% [markdown]
# ### Basic plotting

# %%
preBeijing = oo[(oo.Edition == 2008) & (oo.NOC =='CHN')]
#preBeijing.head()
preBeijing.Gender.value_counts().plot(kind = 'bar');

# %%
BeiJing = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')] #whittle dataset down to the 2008 games and then Chinese only athletes
sns.countplot(x='Medal', data=BeiJing, hue ='Gender');

# %% [markdown]
# ### Changing the order of the display for the x-axis

# %%
sns.countplot(x='Medal', data=BeiJing, hue ='Gender', palette='bwr', order=['Gold','Silver','Bronze']);#change to blue and pink

# %%
oo.head()
oo.set_index('Athlete') # this will not be permanent

oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### Using reset_index( )

# %%
oo.reset_index(inplace=True)  # basically putting things back

# %%
oo.head()  #looking to make sure
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### Making a copy of the original and storing it in another variable

# %%
ath = oo.set_index('Athlete') # moving the altered copy into another variable

# %%
ath.head() # look at it and it will have an index of Athlete.
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.reset_index(inplace=True) # using the inplace = True makes sure we do it to ath  !!!!
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### sort_index( )  allows for all the items to be sorted by that index

# %%
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.set_index('Athlete',inplace=True)
ath.head() # to verify that the index is indeed by the athlete's name
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True) # to sort it athlete name
ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True,ascending=False) # sorting the athletes in REVERSE order, if the 
ath.head()                                   # data has special characters like the umlaut then
                                             # they will appear at the end due to unicode encoding.
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %% [markdown]
# ### loc[. . . ]  selection by name index, TYPICALLY USE THIS FOR INDEXING

# %%
oo.head()
# oo.loc['BOLT, Usain']  # won't work because the data (at this moment) is indexed by the default number index
oo.set_index('Athlete', inplace=True)
oo.loc['BOLT, Usain']   # now it works cuz we set the index to 'Athlete'
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oo.reset_index(inplace=True)
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#oo[oo.Athlete == 'BOLT, Usain'] # traditional way to do it.
oo.loc[oo.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %% [markdown]
# ### iloc[ ]    select by integer index
#
# <ul>
#     <li> iloc[] is primarily integer position based (from 0 to length-1 of the axis) </li>
#     <li>Allows for traditional Pythonic slicing.</li>
# </ul>

# %%
oo.head()  ####   Let's review our dataframe again.
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# #### If I wanted to see the 1,700 th entry I would do the following:

# %%
oo.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
oo.iloc[[1542,2390,6000,15000]]# I could also use a list of integers. This will return the rows corresponding to these indexes
# Out:
#                         Athlete         City  Edition       Sport  \
# 1542     DUCKETT, Richard Louis       London     1908    Lacrosse
# 2390         SAASTAMOINEN, Eino    Stockholm     1912  Gymnastics
# 6000            AGOSTONI, Carlo  Los Angeles     1932     Fencing
# 15000  JENSEN, Poul Richard Hoj     Montreal     1976     Sailing
#
#         Discipline  NOC Gender                                    Event  \
# 1542      Lacrosse  CAN    Men                                 lacrosse
# 2390   Artistic G.  FIN    Men                        team, free system
# 6000       Fencing  ITA    Men                          épée individual
# 15000      Sailing  DEN    Men  fleet/match race keelboat open (Soling)
#
#       Event_gender   Medal
# 1542             M    Gold
# 2390             M  Silver
# 6000             M  Bronze
# 15000            X    Gold

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.iloc[1:4]# traditional Pythonic slicing to look at rows 2-4, skips the 0th item and leaves off the end.
            #   [1   :   4]  <----  unpacking this to show how it returns rows 1 thru 3 ... so three rows skipping 0 & 4
            #    |       | 
            #  include   exclude
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# If I wanted to know how many medals were awarded each time the olympics were held.
# oo.Edition.value_counts().plot(kind='bar'); ## works but ugly

oo.Edition.value_counts().sort_index().plot(kind='bar');

#medalCounts = [(oo.Edition.value_counts().sort_index())]

#sns.countplot(x='Edition', data=medalCounts);

# %%
oo.NOC.value_counts()  # total number medals broken down per country

# now to get the countries that competed in the 2008 olympics.
#countriesAt2008Games = oo[(oo.Edition=='2008') & (oo.NOC)]

lastOlympics = oo[(oo.Edition == 2008)]
lastOlympics.head()
# Out:
#           City  Edition     Sport Discipline           Athlete  NOC Gender  \
# 27174  Beijing     2008  Aquatics     Diving    GALPERIN, Gleb  RUS    Men
# 27175  Beijing     2008  Aquatics     Diving  MITCHAM, Matthew  AUS    Men
# 27176  Beijing     2008  Aquatics     Diving       ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving         WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving      CHEN, Ruolin  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc = pd.read_csv('../data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
type(noc)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### See if there are any rows where column "Country" and "Country.1" differ

# %%
noc[noc['Country'] != noc['Country.1']]  # if nothing returned it means that that result set is empty.(i.e. no difference)
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
##### Here's the MAGIC SAUCE #### The two tables match on columns 'Int Olympic Committee code' and 'NOC'
#
# So we make the 'Int Olympic Committee code' the key in our 2nd table.

noc.set_index('Int Olympic Committee code',inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
lastOlympics.NOC.value_counts()
medals_2008 = lastOlympics.NOC.value_counts() # this is a series.... the 
medals_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# NOR     22
# ROU     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# KEN     14
# ISL     14
# NZL     14
# KAZ     13
#       ...
# IRL      3
# SIN      3
# IND      3
# EST      3
# AUT      3
# LAT      3
# TJK      2
# COL      2
# IRI      2
# POR      2
# ALG      2
# MAR      2
# KGZ      2
# DOM      2
# SUD      1
# ECU      1
# MAS      1
# MRI      1
# AFG      1
# EGY      1
# TUN      1
# PAN      1
# CMR      1
# TOG      1
# CHI      1
# VEN      1
# VIE      1
# ISR      1
# RSA      1
# MDA      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medals_2008'] = medals_2008  ## whenever the index of the series
noc                               ## that we have stored in medals_2008
                                  ## is the same as the index in the 
                                  ## dataframe noc , make a new column
                                  ## and put its total there.
# Out:
#                                            Country ISO code  \
# Int Olympic Committee code
# AFG                                    Afghanistan       AF
# ALB                                        Albania       AL
# ALG                                        Algeria       DZ
# ASA                                American Samoa*       AS
# AND                                        Andorra       AD
# ANG                                         Angola       AO
# ANT                            Antigua and Barbuda       AG
# ARG                                      Argentina       AR
# ARM                                        Armenia       AM
# ARU                                         Aruba*       AW
# AUS                                      Australia       AU
# AUT                                        Austria       AT
# AZE                                     Azerbaijan       AZ
# BAH                                        Bahamas       BS
# ...

# %%
noc[noc.medals_2008.isnull()]  # all of the countries that did not win a metal in the 2008 olympics
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# ALB                                                  Albania       AL
# ASA                                          American Samoa*       AS
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ARU                                                   Aruba*       AW
# BRN                                                  Bahrain       BH
# BAN                                               Bangladesh       BD
# BAR                                                 Barbados       BB
# BIZ                                                   Belize       BZ
# BER                                                 Bermuda*       BM
# BEN                                                    Benin       BJ
# ...

# %%
names = pd.read_csv("../data/nameTable.csv")
names
# Out:
#    ID   Name
# 0   1   Paul
# 1   2  Misty

# %%
ages = pd.read_csv("../data/ageTable.csv")
ages
# Out:
#    ID  age namePerson
# 0   1   45      Misty
# 1   2   49       Paul

# %%
result = pd.merge(names, ages, on='ID')
